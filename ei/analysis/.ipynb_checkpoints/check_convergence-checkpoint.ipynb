# %%
from convergence_testing_functions import *
pd.set_option('display.max_rows', 100)

# %%
data_run = "fiveTypes2k"
ei_run = "EI_scalePop_0_1000_1000"
df = make_trace_plots(data_run, ei_run, "counts")

# %%
df["ccount.D1.C1"].groupby("chain").mean()
# Out:
# chain
# 1    588358.703191
# 2    588748.895021
# 3    194836.075501
# 4    585018.821457
# Name: ccount.D1.C1, dtype: float64

# %%
df["ccount.D1.C2"].groupby("chain").mean()
# Out:
# chain
# 1    121863.974992
# 2    124558.565029
# 3    511238.831493
# 4    126537.955970
# Name: ccount.D1.C2, dtype: float64

# %%
sns.histplot(df["alpha.D1.NOTVOTES"].groupby("chain").mean())
plt.grid()
plt.xlabel("alpha.D1.NOTVOTES chain mean")
plt.show()
