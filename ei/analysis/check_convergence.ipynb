# %%
from convergence_testing_functions import *
pd.set_option('display.max_rows', 100)

# %%
data_run = "AZ_2020_VTDs"
ei_run = "EI2_scalePop_0_1000_1000"
df = make_trace_plots(data_run, ei_run, "counts", 2)
