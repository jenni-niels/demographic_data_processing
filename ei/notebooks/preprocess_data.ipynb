# %%
import geopandas as gpd
import pandas as pd
pd.set_option('display.max_columns', 500)

# %%
gdf = gpd.read_file("../../shapes/GA_precincts/GA_2020_precincts/GA_2020_precincts.shp")

# %%
len(gdf)
# Out:
# 2633

# %%
gdf.tail()
# Out:
#               PREC_match      ID       AREA  DATA DISTRICT CTYSOSID  \
# 2628     WORTH, SHINGLER  868553  38.156772  2693     3215     3215
# 2629       WORTH, SUMNER  868614  47.319323  2692     3214     3214
# 2630  WORTH, SYLVER EAST  868533   5.161374  2690     3212     3212
# 2631    WORTH, SYLVESTER  868495  34.557839  2683     3211     3211
# 2632      WORTH, WARWICK  868653  54.417297  2697     3219     3219
#
#      PRECINCT_I      PRECINCT_N CTYNAME CTYNUMBER CTYNUMBER2 FIPS2  \
# 2628          5        SHINGLER   WORTH       159        159   321
# 2629          4          SUMNER   WORTH       159        159   321
# 2630          2  SYLVESTER EAST   WORTH       159        159   321
# 2631          1       SYLVESTER   WORTH       159        159   321
# 2632          9         WARWICK   WORTH       159        159   321
#
#                      PREC_x COUNTY           BestMatch BestMatchT county_1  \
# ...

# %%
gdf["PRES20D"]
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 2628      45.0
# 2629     113.0
# 2630     225.0
# 2631    1045.0
# 2632     143.0
# Name: PRES20D, Length: 2633, dtype: float64

# %%
list(filter(lambda x:"AMIN" in x, gdf.columns))
# Out:
# ['NH_AMIN',
#  'H_AMIN',
#  'AMINVAP',
#  'AMIN_ANY',
#  'AMINVAP*',
#  'AMINCVAP',
#  'BAMINCVAP',
#  'WAMINCVAP',
#  'AMINCPOP',
#  'BAMINCPOP',
#  'WAMINCPOP',
#  'AMINCVAP*',
#  'AMINCPOP*']

# %%
gdf["AMINCVAP"] == gdf["AMINCVAP*"]
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 2628    False
# 2629    False
# 2630    False
# 2631    False
# 2632    False
# Length: 2633, dtype: bool

# %%
gdf["AMINCVAP"]
# Out:
# 0       30.353383
# 1        0.000000
# 2        2.486216
# 3       10.792683
# 4        5.949885
#           ...
# 2628     0.000000
# 2629     0.000000
# 2630     0.000000
# 2631    63.569754
# 2632     0.000000
# Name: AMINCVAP, Length: 2633, dtype: float64

# %%
gdf["AMINCVAP*"]
# Out:
# 0       30.353383
# 1        0.000000
# 2        2.486216
# 3       13.670732
# 4        9.916476
#           ...
# 2628     2.908125
# 2629     2.030743
# 2630     0.736522
# 2631    71.825986
# 2632     1.137980
# Name: AMINCVAP*, Length: 2633, dtype: float64

# %%
list(gdf.columns)
# Out:
# ['PREC_match',
#  'ID',
#  'AREA',
#  'DATA',
#  'DISTRICT',
#  'CTYSOSID',
#  'PRECINCT_I',
#  'PRECINCT_N',
#  'CTYNAME',
#  'CTYNUMBER',
#  'CTYNUMBER2',
#  'FIPS2',
#  'PREC_x',
#  'COUNTY',
#  'BestMatch',
#  'BestMatchT',
#  'county_1',
#  'precinct',
#  'AG18D',
#  'COA18D',
#  'COI18D',
#  'COL18D',
#  'GOV18D',
#  'LG18D',
#  'SOS18D',
#  'SSS18D',
#  'USH18D',
#  'AG18L',
#  'COA18L',
#  'COI18L',
#  'COL18L',
#  'GOV18L',
#  'LG18L',
#  'SOS18L',
#  'SSS18L',
#  'USH18L',
#  'AG18R',
#  'COA18R',
#  'COI18R',
#  'COL18R',
#  'GOV18R',
#  'LG18R',
#  'SOS18R',
#  'SSS18R',
#  'USH18R',
#  'PREC_y',
#  'CD',
#  'SENDIST',
#  'HDIST',
#  'TOTPOP',
#  'NH_WHITE',
#  'NH_BLACK',
#  'NH_AMIN',
#  'NH_ASIAN',
#  'NH_NHPI',
#  'NH_OTHER',
#  'NH_2MORE',
#  'HISP',
#  'H_WHITE',
#  'H_BLACK',
#  'H_AMIN',
#  'H_ASIAN',
#  'H_NHPI',
#  'H_OTHER',
#  'H_2MORE',
#  'VAP',
#  'HVAP',
#  'WVAP',
#  'BVAP',
#  'AMINVAP',
#  'ASIANVAP',
#  'NHPIVAP',
#  'OTHERVAP',
#  '2MOREVAP',
# ...
